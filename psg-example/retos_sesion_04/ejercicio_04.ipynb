# %%
#Chess game
print("tablero de ajedrez")
print("_________________________________________________")
print("|******      ******      ******      ******      |")
print("|******      ******      ******      ******      |")
print("|******      ******      ******      ******      |")
print("|      ******      ******      ******      ******|")
print("|      ******      ******      ******      ******|")
print("|      ******      ******      ******      ******|")
print("|******      ******      ******      ******      |")
print("|******      ******      ******      ******      |")
print("|******      ******      ******      ******      |")
print("|      ******      ******      ******      ******|")
print("|      ******      ******      ******      ******|")
print("|      ******      ******      ******      ******|")
print("|******      ******      ******      ******      |")
print("|******      ******      ******      ******      |")
print("|******      ******      ******      ******      |")
print("|      ******      ******      ******      ******|")
print("|      ******      ******      ******      ******|")
print("|      ******      ******      ******      ******|")
print("|******      ******      ******      ******      |")
print("|******      ******      ******      ******      |")
print("|******      ******      ******      ******      |")
print("|      ******      ******      ******      ******|")
print("|      ******      ******      ******      ******|")
print("|      ******      ******      ******      ******|")
print("__________________________________________________")
# Out:
# tablero de ajedrez
# _________________________________________________
# |******      ******      ******      ******      |
# |******      ******      ******      ******      |
# |******      ******      ******      ******      |
# |      ******      ******      ******      ******|
# |      ******      ******      ******      ******|
# |      ******      ******      ******      ******|
# |******      ******      ******      ******      |
# |******      ******      ******      ******      |
# |******      ******      ******      ******      |
# |      ******      ******      ******      ******|
# |      ******      ******      ******      ******|
# |      ******      ******      ******      ******|
# |******      ******      ******      ******      |
# |******      ******      ******      ******      |
# |******      ******      ******      ******      |
# |      ******      ******      ******      ******|
# |      ******      ******      ******      ******|
# |      ******      ******      ******      ******|
# |******      ******      ******      ******      |
# |******      ******      ******      ******      |
# |******      ******      ******      ******      |
# |      ******      ******      ******      ******|
# |      ******      ******      ******      ******|
# |      ******      ******      ******      ******|
# __________________________________________________

# %% [markdown]
# # COMO JUGAR AL AJEDREZ
# ### REGLAS BÁSICAS Y 7 PRINCIPIOS
# ***Nunca* es tarde para aprender a jugar al ajedrez: *¡el juego más popular del mundo!* *Aprender sus reglas es muy sencillo:***
#
# **1.** *Configura el tablero de ajedrez.*
#
# **2.** *Aprende a mover las piezas en ajedrez.*
#
# **3.** *Descubre las reglas especiales.*
#
# **4.** *Averigua quien hace la 1ª jugada.*
#
# **5.** *Revisa las normas de cómo ganar.*
#
# **6.** *Estudia las estrategias básicas.*
#
# **7.** *Practica jugando muchas partidas.*
